# %%
# !pip install pyspark

# %%
import pyspark

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
df =pd.read_excel("Attendance.xlsx")
df.head()
# Out:
#   Unnamed: 0  Unnamed: 1  Unnamed: 2                     Unnamed: 3  \
# 0         ID   FULL NAME      MOBILE                          EMAIL
# 1          1      Abburi  6302938978  abburihemalatha2001@gmail.com
# 2          2  Abisha . F  9486084960             abishaf0@gmail.com
# 3          3  Abisha . M  9150394029         abishamurugn@gmail.com
# 4          4      Ahmed   7896857048       ahmedali789685@gmail.com
#
#                          Unnamed: 4 Unnamed: 5  Unnamed: 6    Unnamed: 7  \
# 0                    SKILLASSURE ID     STATUS  TOTAL DAYS  ATTENDANCE %
# 1  Abburi.Hemalatha@skillassure.com        NaN          16       0.21875
# 2          Abisha.F@skillassure.com        NaN           1             0
# 3          Abisha.M@skillassure.com        NaN           2             0
# 4         Ahmed.Ali@skillassure.com        NaN           2           0.5
#
#   Unnamed: 8 Unnamed: 9  ... Unnamed: 29 Unnamed: 30 Unnamed: 31 Unnamed: 32  \
# ...

# %%
from pyspark.sql import SparkSession

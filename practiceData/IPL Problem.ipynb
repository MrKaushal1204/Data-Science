# %%
# Write a program to compute the Net Run Rate (NRR) for a team. 

 
# Net Run Rate = (Run Rate For) - (Run Rate Against) where,  

 
# (Run Rate For) = (Runs Scored by Team) / (Number of Overs Faced)  

# (Run Rate Against) = (Runs Scored by Opponent Team) / (Number of Overs Bowled) 

 

# General rule: 


# Let us say the team scored 100 in 20 overs and the opponent scored 90 in 20 overs. 

# Then the Run Rate for the team is 100/20 = 5.0. 

# The Run Rate of the opponent team is 90/20 = 4.5 

# Therefore Net Run Rate of the team is 5.0 – 4.5 = 0.5 

 

# There is only one exception rule. 

# If any team loses 10 wickets before completion of 20 overs, then the entire 20 overs is taken for computing the Run Rate. 

 

# Example: 

# A team scores 140 in 20 overs and loses 8 wickets. The Run Rate is 140/20 = 7.0 

# If a team score 120 in 15 overs by loses all the 10 wickets, then the Run Rate is 120/20 = 6.0 (and not 120/15 = 8.0) 
#########################################################################################################################


def match_summary():
    











# Enter the name of the Team. 
team_name = input("Enter Team Name: ")
opponent_team_name = input("Enter Team Name: ")

# Accept the following inputs for each match: 


# Score of the Team, Wickets Lost by the Team and Overs Played by the Team.  
score = int(input("Enter the score scored by first team: "))
wickets = int(input("Enter the wickets lost by first team: "))
overs = float(input("Overs played by first team: "))

# Similarly accept inputs for Score of the Opponent Team, Wickets Lost by the Opponent Team and Overs Played by the Opponent Team.  
opponent_score = int(input("Enter the score scored by second team: "))
opponent_wickets = int(input("Enter the wickets lost by second team: "))
opponent_overs = float(input("Overs played by second team: "))

match_summary(score,wickets,overs,opponent_score,opponent_wickets,opponent_overs)

# Accept the above details for 3 matches. Compute the Net Run Rate. 





# Example Input: 

 

# Team Name: Gujarat Titans 

 

# Match: 1 

# Score: 161 

# Wickets: 5 

# Overs: 19.4  

 

# Opposition team: LSG 

# Score: 158 

# Wickets: 6 

# Overs: 20  

 

# Match: 2 

# Score: 171 

# Wickets: 6 

# Overs: 20  

 

# Opposition team: DC  

# Score: 157 

# Wickets: 9 

# Overs: 20  

 

# Match: 3 

 

# Score: 190 

# Wickets: 4 

# Overs: 20  

 

# Opposition team: PBKS 

# Score: 189 

# Wickets: 9 

# Overs: 20  

 

# Display the Net Run Rate.
# Out:
# Enter Team Name: lsg
# Enter Team Name: lalj
# Enter the score scored by first team: 200
# Enter the wickets lost by first team: 10
# Overs played by first team: 20
# Enter the score scored by second team: 190
# Enter the wickets lost by second team: 10
# Overs played by second team: 19.1

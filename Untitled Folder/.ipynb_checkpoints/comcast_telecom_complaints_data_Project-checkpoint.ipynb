# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#  Import data into Python environment.

df = pd.read_csv("Project/Comcast/Comcast_telecom_complaints_data.csv")


# Provide the trend chart for the number of complaints at monthly and daily granularity levels.



# complaint_daily_and _monthly = df[]
df.head(1)
# Out:
#   Ticket #             Customer Complaint      Date Date_month_year  \
# 0   250635  Comcast Cable Internet Speeds  22-04-15       22-Apr-15
#
#          Time        Received Via      City     State  Zip code  Status  \
# 0  3:53:50 PM  Customer Care Call  Abingdon  Maryland     21009  Closed
#
#   Filing on Behalf of Someone
# 0                          No

# %%
df['Month_using_split'] = pd.to_datetime(df['Date_month_year'])

df['Month'] = df['Month_using_split'].dt.month
df['Day'] = df['Month_using_split'].dt.day


# df['month'] = df['Date'].apply( lambda x : int(str(x).split('-')[1]))


# print(df[['Month','Day']].head(3))

groupby_dates = df.groupby('Month')['Customer Complaint'].count()

# print(groupby_dates)

plt.plot(groupby_dates, color = "#046725")
plt.xlabel("Months", size ="15",color ="red")
plt.ylabel("Customer Complain", size ="15", color ="red")
plt.xticks(range(1,13))
plt.grid(True)
plt.show()




# print(type(df['Month_using_split']))

# df['Open'] = lamda df['Status'] : df['Status'] if(df['Status'] == 'Open' or df['Status'] == 'Pending')

# %%
groupby_day = df.groupby('Day')['Customer Complaint'].count()

# %%
# groupby_day

# %%
# fig = plt.figure(figsize=(8,8))
plt.plot(groupby_day,color = "green")
plt.xlabel("Days", size = "15", color= "brown")
plt.ylabel("Frequency",size = 15, color= "brown")

# plt.xticks(range(1,32))
plt.grid()
plt.show()

# %%
# var1 = df['Day'].value_counts().reset_index().sort_values('index')

# %%
# plt.plot(var1['index'],var1['Day'])

# %%
# df.isna().sum()
# print(len(df['Status']))

# %%
df['Customer Complaint'].str.lower().to_frame().value_counts().reset_index().head(15)
# Out:
#           Customer Complaint    0
# 0                    comcast  102
# 1           comcast data cap   30
# 2           comcast internet   29
# 3          comcast data caps   21
# 4            comcast billing   18
# 5             internet speed   15
# 6            comcast service   15
# 7                  data caps   13
# 8   unfair billing practices   13
# 9                   data cap   12
# 10           comcast/xfinity   11
# 11         comcast complaint   11
# 12  comcast internet service   10
# 13                   billing    9
# 14            billing issues    8

# %%
# df['Updated_status'] = 

# print([lst for lst in df['Status']])
# pd.Series.tolist(df)
Updated_status = []
for itr in df['Status']:
#     print(type(itr))
    if itr == 'Closed' or itr == 'Solved':
        Updated_status.append('Closed')
        
    else:
        Updated_status.append('Open')

# %%
df['Updated_status'] = pd.Series(Updated_status)

# %%
df['Updated_status'].value_counts()
# Out:
# Closed    1707
# Open       517
# Name: Updated_status, dtype: int64

# %%
df[['Customer Complaint','Status','Updated_status']].head()
# Out:
#                                   Customer Complaint  Status Updated_status
# 0                      Comcast Cable Internet Speeds  Closed         Closed
# 1       Payment disappear - service got disconnected  Closed         Closed
# 2                                  Speed and Service  Closed         Closed
# 3  Comcast Imposed a New Usage Cap of 300GB that ...    Open           Open
# 4         Comcast not working and no service to boot  Solved         Closed

# %%
# df['Status'].value_counts()

# %%
df.columns
# Out:
# Index(['Ticket #', 'Customer Complaint', 'Date', 'Date_month_year', 'Time',
#        'Received Via', 'City', 'State', 'Zip code', 'Status',
#        'Filing on Behalf of Someone', 'Month_using_split', 'Month', 'Day',
#        'Updated_status'],
#       dtype='object')

# %%
stacked = df[df['Status'] == 'Open']
